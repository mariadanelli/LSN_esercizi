# %%
import matplotlib.pyplot as plt
import numpy as np


# Carica i dati dal file
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 5))
data1 = np.loadtxt('uno.txt')
ax1.hist(data1, 100, (0,1), density=True, color='green', label= 'uniforme')
ax1.set_title ('Uniforme')
ax1.set_xlabel ('random x')
data2 = np.loadtxt('uno exp.txt')
ax2.hist(data2, 100, (0,2.5), density=True, color='red', label= 'esponeziale')
ax2.set_title ('Esponeziale')

data3 = np.loadtxt('uno lor.txt')
ax3.hist(data3, 100, (-30,30) ,density=True,color='blue', label= 'Cauchy Lorentz')
ax3.set_title ('Cauchy Lorentz')


fig.suptitle('Media su 1 elemento di una distribuzione di probabilità')
print ('sono normalizzate bene???')
plt.show()
# Out:
# sono normalizzate bene???

# %%
import matplotlib.pyplot as plt
import numpy as np


# Carica i dati dal file
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 5))
data1 = np.loadtxt('due.txt')
ax1.hist(data1, 100, (0,1), density=True, color='green', label= 'uniforme')
ax1.set_title ('Uniforme')
ax1.set_xlabel ('random x')
data2 = np.loadtxt('due exp.txt')
ax2.hist(data2, 100, (0,2.5), density=True, color='red', label= 'esponeziale')
ax2.set_title ('Esponeziale')

data3 = np.loadtxt('due lor.txt')
ax3.hist(data3, 100, (-30,30) ,density=True,color='blue', label= 'Cauchy Lorentz')
ax3.set_title ('Cauchy Lorentz')


fig.suptitle('Media su 2 variabili che seguono una data distribuzione di probabilità')
print ('sono normalizzate bene???')
plt.show()
# Out:
# sono normalizzate bene???

# %%
import matplotlib.pyplot as plt
import numpy as np


# Carica i dati dal file
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 5))
data1 = np.loadtxt('dieci.txt')
ax1.hist(data1, 100, (0,1), density=True, color='green', label= 'uniforme')
ax1.set_title ('Uniforme')
ax1.set_xlabel ('random x')
data2 = np.loadtxt('dieci exp.txt')
ax2.hist(data2, 100, (0,2.5), density=True, color='red', label= 'esponeziale')
ax2.set_title ('Esponeziale')

data3 = np.loadtxt('dieci lor.txt')
ax3.hist(data3, 100, (-30,30) ,density=True,color='blue', label= 'Cauchy Lorentz')
ax3.set_title ('Cauchy Lorentz')


fig.suptitle('Media su 10 variabili che seguono una data distribuzione di probabilità')
print ('sono normalizzate bene???')
plt.show()
# Out:
# sono normalizzate bene???

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
from scipy.optimize import curve_fit

# Carica i dati dal file
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 5))

data1 = np.loadtxt('cento.txt')
hist1, bins1, _ = ax1.hist(data1, 100, density=True, color='green', label='Uniforme')
ax1.set_xlabel ('random x')
ax1.set_ylabel ('probabilità')

data2 = np.loadtxt('cento exp.txt')
hist2, bins2, _ = ax2.hist(data2, 100, density=True, color='red', label='Esponenziale')
ax2.set_xlabel ('random x')
ax2.set_ylabel ('probabilità')

data3 = np.loadtxt('cento lor.txt')
ax3.hist(data3, 100, (-30,30) ,density=True,color='blue', label= 'Cauchy Lorentz')
ax3.set_xlabel ('random x')
ax3.set_ylabel ('probabilità')

def gaussian_function(x, amplitude, mean, std_dev):
    return amplitude * np.exp(-(x - mean) ** 2 / (2 * std_dev ** 2))

x = np.linspace(0, 1, 10000)

bin_centers1 = 0.5 * (bins1[:-1] + bins1[1:])
params, covariance = curve_fit(gaussian_function, bin_centers1, hist1, p0=[1, np.mean(data1), np.std(data1)])
# Estrai i parametri del fit
amplitude_fit, mean_fit, std_dev_fit = params

x= np.linspace( mean_fit-3*std_dev_fit, mean_fit+3*std_dev_fit)
y= gaussian_function(x, amplitude_fit, mean_fit, std_dev_fit)
ax1.plot(x,y, 'k--',label='fit')
ax1.legend()

x = np.linspace(0, 1, 10000)

bin_centers2= 0.5 * (bins2[:-1] + bins2[1:])
params, covariance = curve_fit(gaussian_function, bin_centers2, hist2, p0=[1, np.mean(data2), np.std(data2)])
# Estrai i parametri del fit
amplitude_fit, mean_fit, std_dev_fit = params

x= np.linspace( mean_fit-3*std_dev_fit, mean_fit+3*std_dev_fit)
y= gaussian_function(x, amplitude_fit, mean_fit, std_dev_fit)
ax2.plot(x,y, 'k--',label='fit')
ax2.legend()

fig.suptitle('Media su 100 elemento di una distribuzione di probabilità')
print ('sono normalizzate bene???')
plt.show()
# Out:
# sono normalizzate bene???
