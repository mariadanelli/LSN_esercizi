# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x = np.arange(100)

# Carica i dati dal file
data = np.loadtxt('media.dat')

x*=1000

plt.errorbar(x,data[:,0]-math.pi,yerr=data[:,1])
plt.xlabel('#throws')
plt.ylabel('<r>-pigr')
plt.grid(True)
plt.show()
print ('boh errore troppo piccolo devo fare la prop?, devo usare la stima della varianza? chiedi a ste' )
# Out:
# boh errore troppo piccolo devo fare la prop?, devo usare la stima della varianza? chiedi a ste

# %% [markdown]
# ciaoooooooooooooo
